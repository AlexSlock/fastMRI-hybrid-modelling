# %% [markdown]
# FILE to easily visualize data for brains and knees (not possible for prostates!)

# %%
from visualize_anatomy import visualize_anatomy

#KNEE:
visualize_anatomy('/DATASERVER/MIC/SHARED/NYU_FastMRI/Knee/multicoil_train', coil_indices=[0, 5, 10], center_fractions=[0.08], accelerations=[4])
# Out:
# Found 973 files in /DATASERVER/MIC/SHARED/NYU_FastMRI/Knee/multicoil_train
# Using file: /DATASERVER/MIC/SHARED/NYU_FastMRI/Knee/multicoil_train/file1000059.h5
# Volume k-space shape: (38, 15, 640, 368)
# Visualizing raw k-space...
# Visualizing fully sampled reconstruction...
# visualize under-sampled k-space by GRAPPA maks
# Visualizing undersampled reconstruction...

# %% [markdown]
# load the figures from /DATASERVER/MIC/GENERAL/STUDENTS/aslock2/figures/

# %%
# BRAIN
visualize_anatomy('/DATASERVER/MIC/SHARED/NYU_FastMRI/Preprocessed/multicoil_train', coil_indices=[0, 1, 2], center_fractions=[0.08], accelerations=[4])
# Out:
# Found 4458 files in /DATASERVER/MIC/SHARED/NYU_FastMRI/Preprocessed/multicoil_train
# Using file: /DATASERVER/MIC/SHARED/NYU_FastMRI/Preprocessed/multicoil_train/file_brain_AXT2_207_2070515.h5
# Volume k-space shape: (16, 4, 640, 320)
# Visualizing raw k-space...
# Visualizing fully sampled reconstruction...
# Visualizing undersampled reconstruction...

# %%
# prostate
# Use a T2 weighted image

# k-space of T2W prostate is differently made:
# = dim (avgs, slices, coils, readout, phase)

# %%
# Prostate: diffusion weighted image

# k-space of DIF weighted prostate is differently made:
# = dim (diffusion, slices, coils, readout, phase)
